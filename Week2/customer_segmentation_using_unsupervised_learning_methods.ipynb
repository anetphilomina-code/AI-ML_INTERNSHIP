# %% [markdown]
# <h2> Imports </h2>

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from time import time
# %matplotlib inline
from sklearn import preprocessing
from sklearn.cluster import KMeans,DBSCAN
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

from datetime import datetime,date

# %%
df = pd.read_csv('bank_transactions.csv')
df.head()
# Out:
#   TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0            T1   C5841053     10/1/94          F   JAMSHEDPUR
# 1            T2   C2142763      4/4/57          M      JHAJJAR
# 2            T3   C4417068    26/11/96          F       MUMBAI
# 3            T4   C5342380     14/9/73          F       MUMBAI
# 4            T5   C9031234     24/3/88          F  NAVI MUMBAI
#
#    CustAccountBalance TransactionDate  TransactionTime  \
# 0            17819.05          2/8/16           143207
# 1             2270.69          2/8/16           141858
# 2            17874.44          2/8/16           142712
# 3           866503.21          2/8/16           142714
# 4             6714.43          2/8/16           181156
#
#    TransactionAmount (INR)
# 0                     25.0
# 1                  27999.0
# 2                    459.0
# 3                   2060.0
# 4                   1762.5

# %%
df.shape
# Out:
# (1048567, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048567 entries, 0 to 1048566
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   TransactionID            1048567 non-null  object
#  1   CustomerID               1048567 non-null  object
#  2   CustomerDOB              1045170 non-null  object
#  3   CustGender               1047467 non-null  object
#  4   CustLocation             1048416 non-null  object
#  5   CustAccountBalance       1046198 non-null  float64
#  6   TransactionDate          1048567 non-null  object
#  7   TransactionTime          1048567 non-null  int64
#  8   TransactionAmount (INR)  1048567 non-null  float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 72.0+ MB

# %%
df.describe().T
# Out:
#                              count           mean            std  min  \
# CustAccountBalance       1046198.0  115403.540056  846485.380601  0.0
# TransactionTime          1048567.0  157087.529393   51261.854022  0.0
# TransactionAmount (INR)  1048567.0    1574.335003    6574.742978  0.0
#
#                                25%        50%        75%           max
# CustAccountBalance         4721.76   16792.18   57657.36  1.150355e+08
# TransactionTime          124030.00  164226.00  200010.00  2.359590e+05
# TransactionAmount (INR)     161.00     459.03    1200.00  1.560035e+06

# %% [markdown]
# **Discover how many nulls in each column**

# %%
df.isna().sum()
# Out:
# TransactionID                 0
# CustomerID                    0
# CustomerDOB                3397
# CustGender                 1100
# CustLocation                151
# CustAccountBalance         2369
# TransactionDate               0
# TransactionTime               0
# TransactionAmount (INR)       0
# dtype: int64

# %% [markdown]
# **Drop all rows that have nulls**

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# TransactionID              0
# CustomerID                 0
# CustomerDOB                0
# CustGender                 0
# CustLocation               0
# CustAccountBalance         0
# TransactionDate            0
# TransactionTime            0
# TransactionAmount (INR)    0
# dtype: int64

# %% [markdown]
# **To know the count of each value in column**

# %%
df['CustGender'].value_counts()
# Out:
# CustGender
# M    760978
# F    280635
# T         1
# Name: count, dtype: int64

# %%
df['CustomerDOB'].value_counts()
# Out:
# CustomerDOB
# 1/1/1800    56292
# 1/1/89        809
# 1/1/90        784
# 6/8/91        698
# 1/1/91        665
#             ...
# 6/9/43          1
# 28/9/48         1
# 12/4/55         1
# 22/3/51         1
# 15/8/05         1
# Name: count, Length: 17233, dtype: int64

# %%
df = df.drop(df[df['CustomerDOB'] == '1/1/1800'].index,axis = 0)

# %%
df['CustomerDOB'].value_counts()
# Out:
# CustomerDOB
# 1/1/89      809
# 1/1/90      784
# 6/8/91      698
# 1/1/91      665
# 1/1/92      631
#            ...
# 15/5/42       1
# 18/7/65       1
# 28/6/45       1
# 18/11/15      1
# 7/1/50        1
# Name: count, Length: 17232, dtype: int64

# %% [markdown]
# **Convert values in "CustomerDOB" column to datetime data type**

# %%
df["CustomerDOB"] = pd.to_datetime(df["CustomerDOB"])
df
# Out:
# /tmp/ipython-input-2080729413.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["CustomerDOB"] = pd.to_datetime(df["CustomerDOB"])
#         TransactionID CustomerID CustomerDOB CustGender   CustLocation  \
# 0                  T1   C5841053  1994-10-01          F     JAMSHEDPUR
# 1                  T2   C2142763  2057-04-04          M        JHAJJAR
# 2                  T3   C4417068  1996-11-26          F         MUMBAI
# 3                  T4   C5342380  2073-09-14          F         MUMBAI
# 4                  T5   C9031234  1988-03-24          F    NAVI MUMBAI
# ...               ...        ...         ...        ...            ...
# 1048562      T1048563   C8020229  1990-08-04          M      NEW DELHI
# 1048563      T1048564   C6459278  1992-02-20          M         NASHIK
# 1048564      T1048565   C6412354  1989-05-18          M      HYDERABAD
# 1048565      T1048566   C6420483  1978-08-30          M  VISAKHAPATNAM
# 1048566      T1048567   C8337524  1984-05-03          M           PUNE
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# 0                  17819.05          2/8/16           143207
# 1                   2270.69          2/8/16           141858
# 2                  17874.44          2/8/16           142712
# 3                 866503.21          2/8/16           142714
# 4                   6714.43          2/8/16           181156
# ...                     ...             ...              ...
# 1048562             7635.19         18/9/16           184824
# 1048563            27311.42         18/9/16           183734
# 1048564           221757.06         18/9/16           183313
# 1048565            10117.87         18/9/16           184706
# 1048566            75734.42         18/9/16           181222
#
#          TransactionAmount (INR)
# 0                           25.0
# 1                        27999.0
# 2                          459.0
# 3                         2060.0
# 4                         1762.5
# ...                          ...
# 1048562                    799.0
# 1048563                    460.0
# 1048564                    770.0
# 1048565                   1000.0
# 1048566                   1166.0
#
# [985322 rows x 9 columns]

# %% [markdown]
# **Substitute any year more than or equal 2022 by 100**

# %%
df.loc[df.CustomerDOB.dt.year >= 2025, 'CustomerDOB']
# Out:
# 1         2057-04-04
# 3         2073-09-14
# 5         2072-08-10
# 15        2068-10-07
# 30        2067-01-21
#              ...
# 1048506   2070-09-20
# 1048510   2048-07-15
# 1048536   2033-05-10
# 1048544   2071-05-10
# 1048552   2071-08-21
# Name: CustomerDOB, Length: 104790, dtype: datetime64[ns]

# %%
df.loc[df.CustomerDOB.dt.year >= 2022, 'CustomerDOB'] = df.loc[df.CustomerDOB.dt.year >= 2022, 'CustomerDOB'] - pd.DateOffset(years = 100)
df.head()
# Out:
#   TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0            T1   C5841053  1994-10-01          F   JAMSHEDPUR
# 1            T2   C2142763  1957-04-04          M      JHAJJAR
# 2            T3   C4417068  1996-11-26          F       MUMBAI
# 3            T4   C5342380  1973-09-14          F       MUMBAI
# 4            T5   C9031234  1988-03-24          F  NAVI MUMBAI
#
#    CustAccountBalance TransactionDate  TransactionTime  \
# 0            17819.05          2/8/16           143207
# 1             2270.69          2/8/16           141858
# 2            17874.44          2/8/16           142712
# 3           866503.21          2/8/16           142714
# 4             6714.43          2/8/16           181156
#
#    TransactionAmount (INR)
# 0                     25.0
# 1                  27999.0
# 2                    459.0
# 3                   2060.0
# 4                   1762.5

# %%
df['Customer age'] = ((pd.to_datetime('today') - df['CustomerDOB']).dt.days / 365.25).round(0)
df.head()
# Out:
#   TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0            T1   C5841053  1994-10-01          F   JAMSHEDPUR
# 1            T2   C2142763  1957-04-04          M      JHAJJAR
# 2            T3   C4417068  1996-11-26          F       MUMBAI
# 3            T4   C5342380  1973-09-14          F       MUMBAI
# 4            T5   C9031234  1988-03-24          F  NAVI MUMBAI
#
#    CustAccountBalance TransactionDate  TransactionTime  \
# 0            17819.05          2/8/16           143207
# 1             2270.69          2/8/16           141858
# 2            17874.44          2/8/16           142712
# 3           866503.21          2/8/16           142714
# 4             6714.43          2/8/16           181156
#
#    TransactionAmount (INR)  Customer age
# 0                     25.0          31.0
# 1                  27999.0          69.0
# 2                    459.0          29.0
# 3                   2060.0          52.0
# 4                   1762.5          38.0

# %%
df['Customer age'].describe().T
# Out:
# count    985322.000000
# mean         40.333645
# std           8.763947
# min           5.000000
# 25%          34.000000
# 50%          38.000000
# 75%          44.000000
# max         103.000000
# Name: Customer age, dtype: float64

# %% [markdown]
# **Convert values in "TransactionDate" column to datetime data type**

# %%
df['TransactionDate'] = pd.to_datetime(df['TransactionDate'])
df.head()
# Out:
# /tmp/ipython-input-766114076.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['TransactionDate'] = pd.to_datetime(df['TransactionDate'])
#   TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0            T1   C5841053  1994-10-01          F   JAMSHEDPUR
# 1            T2   C2142763  1957-04-04          M      JHAJJAR
# 2            T3   C4417068  1996-11-26          F       MUMBAI
# 3            T4   C5342380  1973-09-14          F       MUMBAI
# 4            T5   C9031234  1988-03-24          F  NAVI MUMBAI
#
#    CustAccountBalance TransactionDate  TransactionTime  \
# 0            17819.05      2016-02-08           143207
# 1             2270.69      2016-02-08           141858
# 2            17874.44      2016-02-08           142712
# 3           866503.21      2016-02-08           142714
# 4             6714.43      2016-02-08           181156
#
#    TransactionAmount (INR)  Customer age
# 0                     25.0          31.0
# 1                  27999.0          69.0
# 2                    459.0          29.0
# 3                   2060.0          52.0
# 4                   1762.5          38.0

# %%
plt.hist(df['TransactionDate'].dt.day, color='yellow', edgecolor='black',bins = 2, linewidth=2)
plt.title('Transactions in each month day')
plt.show()

# %%
df['TransactionMonth'] = df['TransactionDate'].dt.month
df['TransactionDay'] = df['TransactionDate'].dt.dayofweek
df.head()
# Out:
#   TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0            T1   C5841053  1994-10-01          F   JAMSHEDPUR
# 1            T2   C2142763  1957-04-04          M      JHAJJAR
# 2            T3   C4417068  1996-11-26          F       MUMBAI
# 3            T4   C5342380  1973-09-14          F       MUMBAI
# 4            T5   C9031234  1988-03-24          F  NAVI MUMBAI
#
#    CustAccountBalance TransactionDate  TransactionTime  \
# 0            17819.05      2016-02-08           143207
# 1             2270.69      2016-02-08           141858
# 2            17874.44      2016-02-08           142712
# 3           866503.21      2016-02-08           142714
# 4             6714.43      2016-02-08           181156
#
#    TransactionAmount (INR)  Customer age  TransactionMonth  TransactionDay
# 0                     25.0          31.0                 2               0
# 1                  27999.0          69.0                 2               0
# 2                    459.0          29.0                 2               0
# 3                   2060.0          52.0                 2               0
# 4                   1762.5          38.0                 2               0

# %%
df
# Out:
#         TransactionID CustomerID CustomerDOB CustGender   CustLocation  \
# 0                  T1   C5841053  1994-10-01          F     JAMSHEDPUR
# 1                  T2   C2142763  1957-04-04          M        JHAJJAR
# 2                  T3   C4417068  1996-11-26          F         MUMBAI
# 3                  T4   C5342380  1973-09-14          F         MUMBAI
# 4                  T5   C9031234  1988-03-24          F    NAVI MUMBAI
# ...               ...        ...         ...        ...            ...
# 1048562      T1048563   C8020229  1990-08-04          M      NEW DELHI
# 1048563      T1048564   C6459278  1992-02-20          M         NASHIK
# 1048564      T1048565   C6412354  1989-05-18          M      HYDERABAD
# 1048565      T1048566   C6420483  1978-08-30          M  VISAKHAPATNAM
# 1048566      T1048567   C8337524  1984-05-03          M           PUNE
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# 0                  17819.05      2016-02-08           143207
# 1                   2270.69      2016-02-08           141858
# 2                  17874.44      2016-02-08           142712
# 3                 866503.21      2016-02-08           142714
# 4                   6714.43      2016-02-08           181156
# ...                     ...             ...              ...
# 1048562             7635.19      2016-09-18           184824
# 1048563            27311.42      2016-09-18           183734
# 1048564           221757.06      2016-09-18           183313
# 1048565            10117.87      2016-09-18           184706
# 1048566            75734.42      2016-09-18           181222
#
#          TransactionAmount (INR)  Customer age  TransactionMonth  \
# 0                           25.0          31.0                 2
# 1                        27999.0          69.0                 2
# 2                          459.0          29.0                 2
# 3                         2060.0          52.0                 2
# 4                         1762.5          38.0                 2
# ...                          ...           ...               ...
# 1048562                    799.0          35.0                 9
# 1048563                    460.0          34.0                 9
# 1048564                    770.0          36.0                 9
# 1048565                   1000.0          47.0                 9
# 1048566                   1166.0          41.0                 9
#
#          TransactionDay
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 1048562               6
# 1048563               6
# 1048564               6
# 1048565               6
# 1048566               6
#
# [985322 rows x 12 columns]

# %%
plt.hist(df['TransactionMonth'], color='yellow', edgecolor='black',bins = 10, linewidth=2)
plt.title('Transactions in each month')
plt.show()

# %%
plt.hist(df['TransactionDay'], color='yellow', edgecolor='black',bins = 10, linewidth=2)
plt.title('Transactions in each day of the week')
plt.show()

# %%
plt.hist(df['TransactionMonth'], color='yellow', edgecolor='black',bins = 10, linewidth=2)
plt.title('Transactions in each month')
plt.show()

# %%
plt.hist(df['TransactionDay'], color='yellow', edgecolor='black',bins = 10, linewidth=2)
plt.title('Transactions in each day of the week')
plt.show()

# %%
pd.options.plotting.backend = 'matplotlib'

df.groupby(df['TransactionMonth']).sum(numeric_only=True).plot(kind='pie', y='TransactionAmount (INR)')
# Out:
# <Axes: ylabel='TransactionAmount (INR)'>

# %%
df.groupby(df['TransactionDay']).sum(numeric_only=True).plot(kind='pie', y='TransactionAmount (INR)')
# Out:
# <Axes: ylabel='TransactionAmount (INR)'>

# %%
df.groupby(df['CustGender']).sum(numeric_only=True).plot(kind='pie', y='TransactionAmount (INR)')
# Out:
# <Axes: ylabel='TransactionAmount (INR)'>

# %% [markdown]
# **Apply label encoder on "CustGender" and "CustLocation" columns**

# %%
le = preprocessing.LabelEncoder()

df['CustGender']= le.fit_transform(df['CustGender'])
df['CustLocation']= le.fit_transform(df['CustLocation'])
df.head()
# Out:
#   TransactionID CustomerID CustomerDOB  CustGender  CustLocation  \
# 0            T1   C5841053  1994-10-01           0          3117
# 1            T2   C2142763  1957-04-04           1          3174
# 2            T3   C4417068  1996-11-26           0          4625
# 3            T4   C5342380  1973-09-14           0          4625
# 4            T5   C9031234  1988-03-24           0          4965
#
#    CustAccountBalance TransactionDate  TransactionTime  \
# 0            17819.05      2016-02-08           143207
# 1             2270.69      2016-02-08           141858
# 2            17874.44      2016-02-08           142712
# 3           866503.21      2016-02-08           142714
# 4             6714.43      2016-02-08           181156
#
#    TransactionAmount (INR)  Customer age  TransactionMonth  TransactionDay
# 0                     25.0          31.0                 2               0
# 1                  27999.0          69.0                 2               0
# 2                    459.0          29.0                 2               0
# 3                   2060.0          52.0                 2               0
# 4                   1762.5          38.0                 2               0

# %% [markdown]
# **Drop unused columns**

# %%
df = df.drop(['TransactionID','CustomerID','CustomerDOB','TransactionDate','TransactionTime'],axis=1)
df
# Out:
#          CustGender  CustLocation  CustAccountBalance  \
# 0                 0          3117            17819.05
# 1                 1          3174             2270.69
# 2                 0          4625            17874.44
# 3                 0          4625           866503.21
# 4                 0          4965             6714.43
# ...             ...           ...                 ...
# 1048562           1          5066             7635.19
# 1048563           1          4943            27311.42
# 1048564           1          2954           221757.06
# 1048565           1          7979            10117.87
# 1048566           1          5843            75734.42
#
#          TransactionAmount (INR)  Customer age  TransactionMonth  \
# 0                           25.0          31.0                 2
# 1                        27999.0          69.0                 2
# 2                          459.0          29.0                 2
# 3                         2060.0          52.0                 2
# 4                         1762.5          38.0                 2
# ...                          ...           ...               ...
# 1048562                    799.0          35.0                 9
# 1048563                    460.0          34.0                 9
# 1048564                    770.0          36.0                 9
# 1048565                   1000.0          47.0                 9
# 1048566                   1166.0          41.0                 9
#
#          TransactionDay
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 1048562               6
# 1048563               6
# 1048564               6
# 1048565               6
# 1048566               6
#
# [985322 rows x 7 columns]

# %%
columns_names=['CustGender','CustLocation','CustAccountBalance','TransactionAmount (INR)','Customer age','TransactionMonth','TransactionDay']

# %%
df[columns_names].describe().T
# Out:
#                             count           mean            std  min  \
# CustGender               985322.0       0.723067       0.447483  0.0
# CustLocation             985322.0    3596.407063    2084.145964  0.0
# CustAccountBalance       985322.0  106061.188580  817905.353760  0.0
# TransactionAmount (INR)  985322.0    1452.425149    6139.765064  0.0
# Customer age             985322.0      40.333645       8.763947  5.0
# TransactionMonth         985322.0       7.349036       2.633786  1.0
# TransactionDay           985322.0       2.999948       1.981179  0.0
#
#                                25%      50%       75%           max
# CustGender                  0.0000      1.0      1.00  1.000000e+00
# CustLocation             1805.0000   3531.0   5066.00  8.163000e+03
# CustAccountBalance       4582.1325  16006.3  53759.08  1.150355e+08
# TransactionAmount (INR)   151.0000    431.0   1125.00  1.560035e+06
# Customer age               34.0000     38.0     44.00  1.030000e+02
# TransactionMonth            6.0000      8.0      9.00  1.200000e+01
# TransactionDay              1.0000      3.0      5.00  6.000000e+00

# %%
df[df['TransactionAmount (INR)'] == 0].count()
# Out:
# CustGender                 708
# CustLocation               708
# CustAccountBalance         708
# TransactionAmount (INR)    708
# Customer age               708
# TransactionMonth           708
# TransactionDay             708
# dtype: int64

# %%
df = df.drop(df[df['TransactionAmount (INR)'] == 0].index,axis = 0)

# %%
df[df['TransactionAmount (INR)'] == 0].count()
# Out:
# CustGender                 0
# CustLocation               0
# CustAccountBalance         0
# TransactionAmount (INR)    0
# Customer age               0
# TransactionMonth           0
# TransactionDay             0
# dtype: int64

# %%
df['CustLocation'].value_counts()
# Out:
# CustLocation
# 4625    97605
# 672     77688
# 5066    76307
# 2689    70447
# 1805    67263
#         ...
# 4544        1
# 5520        1
# 6240        1
# 1073        1
# 6402        1
# Name: count, Length: 8161, dtype: int64

# %% [markdown]
# **Plotting histograms of the columns to know if data is skewed or not**

# %%
for i in columns_names:
    plt.hist(df[i], color='yellow', edgecolor='black', linewidth=2)
    plt.title(i)
    plt.show()

# %% [markdown]
# **Plotting boxplots of the columns to know if each column has outliers or not**

# %%
for i in columns_names:
    sns.boxplot(y=df[i])
    plt.title('Boxplot')
    plt.show()

# %% [markdown]
# **Apply Normalization method "Standard scaler"**

# %%
s = StandardScaler()
df = s.fit_transform(df)
df = pd.DataFrame(df,columns=columns_names)
df.head()
# Out:
#    CustGender  CustLocation  CustAccountBalance  TransactionAmount (INR)  \
# 0   -1.615620     -0.230053           -0.107862                -0.232580
# 1    0.618957     -0.202705           -0.126881                 4.322077
# 2   -1.615620      0.493473           -0.107794                -0.161917
# 3   -1.615620      0.493473            0.930237                 0.098754
# 4   -1.615620      0.656602           -0.121445                 0.050316
#
#    Customer age  TransactionMonth  TransactionDay
# 0     -1.065074         -2.031003       -1.514184
# 1      3.271018         -2.031003       -1.514184
# 2     -1.293289         -2.031003       -1.514184
# 3      1.331187         -2.031003       -1.514184
# 4     -0.266320         -2.031003       -1.514184

# %%
plt.scatter(df.CustLocation, df['TransactionAmount (INR)'])

# %%
plt.scatter(df['Customer age'], df['TransactionAmount (INR)'])

# %%
X = df[['Customer age','TransactionAmount (INR)']].values
Y = df[['CustLocation','TransactionAmount (INR)']].values

# %% [markdown]
# <h1> Centroid-based clustering</h1>

# %% [markdown]
# <h3>K-Means algorithm</h3>
#
# - Select the number of clusters K
# - Initialize the K centroids
# - Assign each data point to their closest centroid
# - For each cluster calculate the average of its assigned examples and let it the new position for that centroid
# - Reassign each data example to the new closest centroid of each cluster
# - Update the centroid position
# - The model is ready

# %%
# !pip install yellowbrick
# Out:
# Requirement already satisfied: yellowbrick in /usr/local/lib/python3.12/dist-packages (1.5)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from yellowbrick) (3.10.0)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from yellowbrick) (1.16.2)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from yellowbrick) (1.6.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from yellowbrick) (2.0.2)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from yellowbrick) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->yellowbrick) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->yellowbrick) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.17.0)

# %%
import random
from yellowbrick.cluster import KElbowVisualizer
model = KMeans( random_state = 42)

visualizer = KElbowVisualizer(model, k=(2,30), timings=False)
visualizer2 = KElbowVisualizer(model, k=(2,30), timings=False)

# %% [markdown]
# <h3> Centroid-based clustering based on customer's age</h3>

# %%
visualizer.fit(X)
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
kmeans_x = KMeans(n_clusters = 8, random_state = 42)
x_kmeans = kmeans_x.fit_predict(X)

# %% [markdown]
# <h3> Centroid-based clustering based on customer's location</h3>

# %%
visualizer2.fit(Y)
visualizer2.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# distortion : the sum of squared distances of all points to their assigned cluster centers.

# %%
kmeans_y = KMeans(n_clusters = 8, random_state = 42)
y_kmeans = kmeans_y.fit_predict(Y)

# %%
centroids_x = kmeans_x.cluster_centers_
centroids_y = kmeans_y.cluster_centers_

print(centroids_x,centroids_y)
# Out:
# [[-7.87876299e-01 -1.29654323e-01]
#  [ 1.04660660e+00 -2.66298573e-02]
#  [ 9.45475302e-01  1.84202489e+01]
#  [ 9.48111652e-01  9.55205313e+01]
#  [ 8.04301212e-01  7.39873219e+00]
#  [-4.91938859e-02 -8.82785690e-02]
#  [ 2.49449814e-01  2.36027275e+00]
#  [ 3.09128158e+00  8.55152532e-02]] [[-5.15321110e-01 -1.02155207e-01]
#  [ 6.00643624e-01 -8.74975605e-02]
#  [-7.96563363e-02  1.73363017e+01]
#  [ 2.14394001e-01  9.29141067e+01]
#  [-2.54643617e-02  1.82831780e+00]
#  [ 1.69490112e+00 -9.38081044e-02]
#  [ 2.72822403e-02  5.79218430e+00]
#  [-1.34307295e+00 -9.68567349e-02]]

# %%
df['cluster_age_km'] = x_kmeans
df['cluster_location_km'] = y_kmeans
df.head()
# Out:
#    CustGender  CustLocation  CustAccountBalance  TransactionAmount (INR)  \
# 0   -1.615620     -0.230053           -0.107862                -0.232580
# 1    0.618957     -0.202705           -0.126881                 4.322077
# 2   -1.615620      0.493473           -0.107794                -0.161917
# 3   -1.615620      0.493473            0.930237                 0.098754
# 4   -1.615620      0.656602           -0.121445                 0.050316
#
#    Customer age  TransactionMonth  TransactionDay  cluster_age_km  \
# 0     -1.065074         -2.031003       -1.514184               0
# 1      3.271018         -2.031003       -1.514184               6
# 2     -1.293289         -2.031003       -1.514184               0
# 3      1.331187         -2.031003       -1.514184               1
# 4     -0.266320         -2.031003       -1.514184               5
#
#    cluster_location_km
# 0                    0
# 1                    6
# 2                    1
# 3                    1
# 4                    1

# %%
# get centroids
cen_xx = [i[0] for i in centroids_x]
cen_xy = [i[1] for i in centroids_x]

cen_yx = [i[0] for i in centroids_y]
cen_yy = [i[1] for i in centroids_y]

## add to df
df['cen_xx'] = df.cluster_age_km.map({0:cen_xx[0], 1:cen_xx[1], 2:cen_xx[2],3:cen_xx[3], 4:cen_xx[4], 5:cen_xx[5],6:cen_xx[6], 7:cen_xx[7]})
df['cen_xy'] = df.cluster_age_km.map({0:cen_xy[0], 1:cen_xy[1], 2:cen_xy[2],3:cen_xy[3], 4:cen_xy[4], 5:cen_xy[5],6:cen_xy[6], 7:cen_xy[7]})

df['cen_yx'] = df.cluster_location_km.map({0:cen_yx[0], 1:cen_yx[1], 2:cen_yx[2],3:cen_yx[3], 4:cen_yx[4], 5:cen_yx[5],6:cen_yx[6], 7:cen_yx[7]})
df['cen_yy'] = df.cluster_location_km.map({0:cen_yy[0], 1:cen_yy[1], 2:cen_yy[2],3:cen_yy[3], 4:cen_yy[4], 5:cen_yy[5],6:cen_yy[6], 7:cen_yy[7]})
# Makes it easy to calculate distances to centroids, or to visualize points with their cluster centers.
# define and map colors
colors = ['red', 'yellow', 'grey', 'green','blue','orange','pink','brown']
df['color_age_km'] = df.cluster_age_km.map({0:colors[0], 1:colors[1], 2:colors[2],3:colors[3],4:colors[4],5:colors[5],6:colors[6],7:colors[7]})
df['color_location_km'] = df.cluster_location_km.map({0:colors[0], 1:colors[1], 2:colors[2],3:colors[3],4:colors[4],5:colors[5],6:colors[6],7:colors[7]})

# %% [markdown]
# Visualization:
#
# You can plot data points colored by cluster and overlay centroids.
#
# Helps see how well KMeans separated your data.
#
# Distance Calculations:
#
# With centroid coordinates mapped to each row, you can compute distances from each point to its cluster center for analysis.
#
# Data Analysis / Reporting:
#
# You can segment or filter based on clusters easily.
#
# Useful in marketing, regional analysis, or demographic studies.

# %%
plt.figure(num=None, figsize=(20, 20), facecolor='w', edgecolor='k')
plt.scatter(df['Customer age'], df['TransactionAmount (INR)'], c=df.color_age_km)
plt.scatter(df['cen_xx'], df['cen_xy'],marker = '*',s=500, c='black')
#plt.xlim([0, 100])
plt.ylim([-0.5, 20])
# Out:
# (-0.5, 20.0)

# %%
plt.figure(num=None, figsize=(20, 30), facecolor='w', edgecolor='k')
plt.scatter(df['CustLocation'], df['TransactionAmount (INR)'], c=df.color_location_km)
plt.scatter(df['cen_yx'], df['cen_yy'],marker = '*',s=500, c='black')
#plt.xlim([0, 8500])
plt.ylim([-0.5, 20])
# Out:
# (-0.5, 20.0)

# %% [markdown]
# <h1>Hierarchical clustering</h1>

# %% [markdown]
# Hierarchical clustering is where you build a dendrogram to represent data, where each group links to two or more successor groups. The groups are nested and organized as a tree, which ideally ends up as a meaningful classification scheme.
#
# Each node in the cluster tree contains a group of similar data; Nodes group on the graph next to other, similar nodes. Clusters at one level join with clusters in the next level up, using a degree of similarity. The process carries on until all nodes are in the tree, which gives a visual snapshot of the data contained in the whole set. The total number of clusters is not predetermined before you start the tree creation.

# %% [markdown]
# <h3>Agglomerative</h3>

# %% [markdown]
# This is a "bottom-up" approach: each observation starts in its own cluster, and pairs of clusters are merged as one moves up the hierarchy.

# %% [markdown]
# #### Divisive:
# "top down "

# %% [markdown]
# <h3>Hierarchical clustering based on customer's age</h3>

# %%
X_H = pd.DataFrame(X).sample(20000)

# %%
import scipy.cluster.hierarchy as sch
plt.figure(figsize=(20, 10))
dendogram_age = sch.dendrogram(sch.linkage(X_H, method='ward'))
plt.title("Dendogram")
plt.xlabel("Customers")
plt.ylabel("Euclidean distances")
plt.show()

# %%
unique_colors_age = set(dendogram_age['color_list'])
num_clusters_age = len(unique_colors_age)-1
#Subtracts 1 because the dendrogram may include a default color for merged branches above the threshold.
print("Optimal number of clusters is : ", num_clusters_age)
# Out:
# Optimal number of clusters is :  3

# %%
from sklearn.cluster import AgglomerativeClustering
cluster_age = AgglomerativeClustering(n_clusters=num_clusters_age, metric='euclidean', linkage='ward')
cluster_age.fit_predict(X_H)
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %% [markdown]
# Noise points are data points that don’t clearly belong to any cluster. They are often considered outliers or anomalies in clustering.

# %%
plt.figure(num=None, figsize=(20, 10), facecolor='w', edgecolor='k')
plt.scatter(X_H[0], X_H[1], c=cluster_age.labels_, cmap='viridis');
#plt.xlim(-1,1.5)
plt.ylim(-0.5,6)
# Out:
# (-0.5, 6.0)

# %% [markdown]
# <h3>Hierarchical based on customer's location</h3>

# %%
Y_H = pd.DataFrame(Y).sample(20000)

# %%
import scipy.cluster.hierarchy as sch
plt.figure(figsize=(20, 10))

dendogram_loc = sch.dendrogram(sch.linkage(Y_H, method='ward'))
plt.title("Dendogram")
plt.xlabel("Customers")
plt.ylabel("Euclidean distances")
plt.show()

# %%
unique_colors_loc = set(dendogram_loc['color_list'])
num_clusters_loc = len(unique_colors_loc)-1
print("Optimal number of clusters is : ", num_clusters_loc)
# Out:
# Optimal number of clusters is :  2

# %%
from sklearn.cluster import AgglomerativeClustering
cluster_loc = AgglomerativeClustering(n_clusters=num_clusters_loc, metric='euclidean', linkage='ward')
cluster_loc.fit_predict(Y_H)
# Out:
# array([1, 1, 1, ..., 1, 1, 0])

# %%
plt.figure(num=None, figsize=(20, 10), facecolor='w', edgecolor='k')
plt.scatter(Y_H[0], Y_H[1], c=cluster_loc.labels_, cmap='viridis');
#plt.xlim(-1,1.5)
plt.ylim(-0.25,10)
# Out:
# (-0.25, 10.0)

# %% [markdown]
#  DBSCAN CLUSTERING USING CUSTOMERS AGE

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt

# Step 1: Scale data (important for DBSCAN)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_H) # Apply scaler to the sampled data

# Step 2: Apply DBSCAN
dbscan = DBSCAN(eps=0.3, min_samples=10)
labels = dbscan.fit_predict(X_scaled)

# Step 3: Add cluster labels to DataFrame
X_H_clustered = X_H.copy() # Create a copy to store cluster labels
X_H_clustered['Cluster'] = labels

# Step 4: Visualize clusters
plt.figure(figsize=(8,6))
plt.scatter(X_H_clustered[0], X_H_clustered[1], c=X_H_clustered['Cluster'], cmap='plasma')
plt.xlabel('Customer Age')
plt.ylabel('Transaction Amount (INR)')
plt.title('DBSCAN Clustering (Age vs Transaction Amount)')
plt.show()

# %% [markdown]
# DBSCAN CLUSTERING USING CUSTOMERS LOCATION

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt


scaler = StandardScaler()
Y_scaled = scaler.fit_transform(Y_H)


dbscan = DBSCAN(eps=0.5, min_samples=5)
labels = dbscan.fit_predict(Y_scaled)

Y_H_clustered = Y_H.copy()
Y_H_clustered['Cluster'] = labels


plt.figure(figsize=(8,6))
plt.scatter(Y_H_clustered[0], Y_H_clustered[1], c=Y_H_clustered['Cluster'], cmap='plasma')
plt.xlabel('Customer Location')
plt.ylabel('Transaction Amount (INR)')
plt.title('DBSCAN Clustering (Location vs Transaction Amount)')
plt.show()

# %%
from sklearn.metrics import silhouette_score, adjusted_rand_score

sc = silhouette_score(X_H_clustered[[0, 1]], labels)
print("Silhouette Coefficient:%0.2f" % sc)
ari = adjusted_rand_score(Y_H_clustered['Cluster'], labels)
print("Adjusted Rand Index: %0.2f" % ari)
# Out:
# Silhouette Coefficient:0.65
# Adjusted Rand Index: 0.01
